# %%
#intro

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
### Shahid Afridi score in last 20 years in odis


2009	313
2010	601
2011	462
2012	182
2013	441
2014	354
2015	194

Reference: http://www.howstat.com/cricket/Statistics/Players/PlayerYears_ODI.asp?PlayerID=2152

# %%
#Lets consider first 10 years; x = years and y = runs

x = [2009,2010,2011,2012,2013,2014,2015]
y = [313,601,462,182,441,354,194]

# %%
plt.xlabel('Years')
plt.ylabel('Runs')
plt.title('Shahid Afridi score in his last 07 years')

plt.plot(x,y,color='green',linewidth = 12)

# %%
plt.plot(x,y,color='green',linewidth = 5,linestyle = 'dotted')
