# %% [markdown]
# ## Pie Charts

# %% [markdown]
# Pie charts are generally used to show percentage or proportional data and usually the percentage represented by each category is provided next to the corresponding slice of pie. Pie charts are good for displaying data for around 6 categories or fewer.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ## UseCase
#
# Visualize Pakistan's provinces on the basis of their landarea on pie chart.
#
# Dataset: https://www.thoughtco.com/pakistan-provinces-and-capital-territory-1435276

# %%
Pak_Provinces_landArea = [347190,205345 ,140914 ,74521]
Province_labels = ["Balochistan","Punjab","Sindh ","KPK"]

# %%
plt.pie(Pak_Provinces_landArea,labels = Province_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x266ddd406d8>,
# ...
#  [Text(0.16494759395238226, 1.087562545902221, 'Balochistan'),
#   Text(-0.9440559028560254, -0.5645869749495599, 'Punjab'),
#   Text(0.4127596288739218, -1.0196222284610426, 'Sindh '),
#   Text(1.0492815834806457, -0.33016383594868326, 'KPK')])

# %%
plt.axis("equal")
plt.pie(Pak_Provinces_landArea,labels=Province_labels, shadow=True, autopct='%1.1f%%',radius=1.5)
plt.show()

# %%
plt.axis("equal")
plt.pie(Pak_Provinces_landArea,labels=Province_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode = [0.1,0.1,0.1,0.1])
plt.show()

# %%
plt.axis("equal")
plt.pie(Pak_Provinces_landArea,labels=Province_labels, shadow=True, autopct='%1.1f%%',radius=1.5,explode = [0.1,0.1,0.1,0.1],counterclock=True, startangle=180)
plt.show()
